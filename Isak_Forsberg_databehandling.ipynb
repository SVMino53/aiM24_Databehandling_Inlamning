# %% [markdown]
# **Import needed libraries**

# %%
import pandas as pd
import seaborn as sns
import plotly_express as px
import numpy as np
from typing import (Any, Callable)

import matplotlib.pyplot as plt

import warnings

warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 - Getting started

# %% [markdown]
# This project will be centered around the Chicago Crime & selected Census data. Start of by downloading both datasets.

# %% [markdown]
# **1.1** Read through the documentation for both datasets. Do this *thoroughly*!
#
# Chicago crime data : https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-Present/ijzp-q8t2
#
# Chicago census data : https://data.cityofchicago.org/Health-Human-Services/Census-Data-Selected-socioeconomic-indicators-in-C/kn9c-c2s2

# %% [markdown]
# **1.2** Now download both datasets as .csv files. You get the option to download by frist clicking on the 'Export' tab. Make sure you select the data in CSV format.
#
# Be mindful that the crime dataset is over 2GB in size, so it might take awhile to download.
#
# Once downloaded, rename the files chicago_crime.csv & chicago_census.csv, respectively, and put them in the same folder as this notebook.

# %% [markdown]
# **1.3** Load data. The following reads should now work.

# %%
chicago_crime_2001_to_2024_df = pd.read_csv('chicago_crime.csv')
chicago_census_2008_to_2012_df = pd.read_csv('chicago_census.csv')

# %%
# Checking a bit of the data frame

chicago_crime_2001_to_2024_df.head()
# Out:
#          ID Case Number                    Date                 Block  IUCR  \
# 0  11037294    JA371270  03/18/2015 12:00:00 PM     0000X W WACKER DR  1153
# 1  11646293    JC213749  12/20/2018 03:00:00 PM  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333  05/01/2016 12:25:00 AM   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511  12/20/2018 04:00:00 PM    045XX N ALBANY AVE  2820
# 4  11645601    JC212935  06/01/2014 12:01:00 AM   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %% [markdown]
# **1.4** The census data only contains records that apply for the period 2008-2012, while the crime dataset runs from 2001-2024.
#
# Therefore, begin by filtering the crime data so that you get a dataframe that contains records only for the period 2008-2012.
#
# *Hint*: You'll be filtering based on date quite alot in this project, and it's therefore very advisable to transform the existing *Date* column into datetime-format.
#
# To simplify further, you could perhaps also create new columns that indicate *Year*, *Month*, *Day* and *Hour*.
#
# You might also find that other types of indicator columns could be useful. Feel free to come back and add them here later.
#
# **Important:** For the remainder of this project, we will only work with data for the year 2008-2012.

# %%
# Checking the date format

chicago_crime_2001_to_2024_df.head()["Date"]
# Out:
# 0    03/18/2015 12:00:00 PM
# 1    12/20/2018 03:00:00 PM
# 2    05/01/2016 12:25:00 AM
# 3    12/20/2018 04:00:00 PM
# 4    06/01/2014 12:01:00 AM
# Name: Date, dtype: object

# %%
# Convert the 'Date' column to datetime format

chicago_crime_2001_to_2024_df['Date'] = pd.to_datetime(chicago_crime_2001_to_2024_df["Date"], format="%m/%d/%Y %I:%M:%S %p")

# %%
# Checking that the dates have been accurately converted

chicago_crime_2001_to_2024_df.head()
# Out:
#          ID Case Number                Date                 Block  IUCR  \
# 0  11037294    JA371270 2015-03-18 12:00:00     0000X W WACKER DR  1153
# 1  11646293    JC213749 2018-12-20 15:00:00  023XX N LOCKWOOD AVE  1154
# 2  11645836    JC212333 2016-05-01 00:25:00   055XX S ROCKWELL ST  1153
# 3  11645959    JC211511 2018-12-20 16:00:00    045XX N ALBANY AVE  2820
# 4  11645601    JC212935 2014-06-01 00:01:00   087XX S SANGAMON ST  1153
#
#          Primary Type                              Description  \
# 0  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT $300 AND UNDER
# 2  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
# 3       OTHER OFFENSE                         TELEPHONE THREAT
# 4  DECEPTIVE PRACTICE      FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
# Create a new dataframe with crime records only the period 2008-2012

year_2008_to_2012_filter = chicago_crime_2001_to_2024_df["Date"].dt.year.between(2008, 2012)

chicago_crime_2008_to_2012_df = chicago_crime_2001_to_2024_df[year_2008_to_2012_filter].reset_index(drop=True)

# %%
# Checking that the correct data is in the data frame

chicago_crime_2008_to_2012_df.head()
# Out:
#          ID Case Number                Date                     Block  IUCR  \
# 0  11645833    JC213044 2012-05-05 12:25:00           057XX W OHIO ST  1153
# 1  11646447    JC213946 2008-10-24 14:30:00  036XX N NARRAGANSETT AVE  1153
# 2  11031104    JA362043 2008-07-24 00:01:00       031XX W FILLMORE ST  1563
# 3  11648237    JC216157 2012-01-01 12:00:00      115XX S CAMPBELL AVE  1153
# 4  11648822    JC216887 2011-12-13 00:00:00    115XX S MARSHFIELD AVE  1153
#
#          Primary Type                          Description  \
# 0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 1  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 2         SEX OFFENSE                CRIMINAL SEXUAL ABUSE
# 3  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
# 4  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#   Location Description  Arrest  Domestic  ...  Ward  Community Area  FBI Code  \
# ...

# %%
# Continue checking

min_year = chicago_crime_2008_to_2012_df["Date"].dt.year.min()
max_year = chicago_crime_2008_to_2012_df["Date"].dt.year.max()
print(f"min year in 'Date': {min_year}")
print(f"max year in 'Date': {max_year}")
# Out:
# min year in 'Date': 2008
# max year in 'Date': 2012

# %% [markdown]
# # 2 - Cleaning up the mess

# %% [markdown]
# **Note:** The rest of the problems don't really require you to finish this section - you could revisit these questions at a later time.
#
# Bear in mind though that the numbers you aquire in the problems ahead may or may not change a bit, depending on how you choose to treat the duplicates and missing values here.

# %% [markdown]
# **2.1** How many duplicated rows are there in crime data set? If there are any, remove them.

# %%
duplicated_mask = chicago_crime_2008_to_2012_df.duplicated()
chicago_crime_2008_to_2012_df[duplicated_mask]
# Out:
# Empty DataFrame
# Columns: [ID, Case Number, Date, Block, IUCR, Primary Type, Description, Location Description, Arrest, Domestic, Beat, District, Ward, Community Area, FBI Code, X Coordinate, Y Coordinate, Year, Updated On, Latitude, Longitude, Location]
# Index: []
#
# [0 rows x 22 columns]

# %% [markdown]
# **Answer:** There are no duplicated rows in the data frame.
# **HOWEVER!** If we exclude the "ID" column from our duplicate check, we find that there are duplicated cases which can cause faulty data evaluation.

# %%
duplicated_mask = chicago_crime_2008_to_2012_df.iloc[:, 1:].duplicated()
chicago_crime_2008_to_2012_df[duplicated_mask].head()
# Out:
#            ID Case Number                Date                     Block  IUCR  \
# 351763  20546    HV412015 2012-08-02 12:50:00         006XX N AVERS AVE  0110
# 351801  19393    HS313197 2010-05-18 06:37:00           031XX W 48TH PL  0110
# 351811  19439    HS350729 2010-06-09 13:32:00  047XX S FORRESTVILLE AVE  0110
# 351854  20139    HT576362 2011-11-05 17:05:00           004XX E 87TH ST  0110
# 351864  19696    HS638640 2010-11-30 00:55:00          111XX S BELL AVE  0110
#
#        Primary Type          Description Location Description  Arrest  \
# 351763     HOMICIDE  FIRST DEGREE MURDER               STREET   False
# 351801     HOMICIDE  FIRST DEGREE MURDER                 AUTO    True
# 351811     HOMICIDE  FIRST DEGREE MURDER                PORCH    True
# 351854     HOMICIDE  FIRST DEGREE MURDER                 AUTO    True
# 351864     HOMICIDE  FIRST DEGREE MURDER            APARTMENT    True
#
#         Domestic  ...  Ward  Community Area  FBI Code  X Coordinate  \
# ...

# %% [markdown]
# For now, I choose not to remove these duplicates as there may be a reason for their inclusion in the data set that I am unaware of.

# %% [markdown]
# **2.2** What columns in the crime dataset has missing values, and how many are they?

# %%
column_nan_amount = {column: chicago_crime_2008_to_2012_df[column].isnull().sum() for column in chicago_crime_2008_to_2012_df.columns if chicago_crime_2008_to_2012_df[column].isnull().sum() > 0}
missing_values_df = pd.DataFrame({"Column Name": column_nan_amount.keys(), "# Of Missing Values": column_nan_amount.values()})
missing_values_df
# Out:
#             Column Name  # Of Missing Values
# 0  Location Description                 1051
# 1              District                   40
# 2                  Ward                   46
# 3        Community Area                  854
# 4          X Coordinate                16327
# 5          Y Coordinate                16327
# 6              Latitude                16327
# 7             Longitude                16327
# 8              Location                16327

# %% [markdown]
# **2.3** Now, for all the columns with missing values you identified, chose one of the following:
#
#         a) remove the entire row with the missing value
#         b) replace the missing values with another suitable value
#         c) don't do anything, leave the missing values as is
#
# All options above are completely valid! However, I want you to, for all columns with missing values, **clearly** argue for why you chose to do what you do.

# %% [markdown]
# **Answer:**
# I decide to not do anything as I don't know fully what the data will be used for yet. When I encounter tasks requiring analysis of columns with
# missing data, I will make a new data frame and decide what to do with the missing data at that point.

# %% [markdown]
# ## 3 - The Birds Eye

# %% [markdown]
# **3.1** Do some exploratory analysis on the dataset and try to get a sense of the data you're working with.

# %% [markdown]
# **3.1** How many crimes records exists for the period 2008-2012, in total?

# %%
print(f"There are {len(chicago_crime_2008_to_2012_df)} crime records in the data frame.")
# Out:
# There are 1878951 crime records in the data frame.

# %% [markdown]
# **3.2** What's the number of recorded crimes each of the years, individually?

# %%
yearly_records = chicago_crime_2008_to_2012_df["Date"].dt.year.value_counts()
yearly_records_df = pd.DataFrame({"Year": yearly_records.index, "# Of Records": yearly_records.values}).set_index("Year")
yearly_records_df
# Out:
#       # Of Records
# Year
# 2008        427198
# 2009        392848
# 2010        370541
# 2011        352020
# 2012        336344

# %%
ax = sns.barplot(yearly_records_df, x="Year", y="# Of Records")
ax.bar_label(ax.containers[0], fmt=lambda x: f"{int(x)}\nrecords", label_type="center", color="white")
ax.set_title("Number of recorded crimes in Chicago per year\n2008-2012")
ax.set_ylim(0, 450000)
ax.set_ylabel("Recorded crimes")
plt.show()

# %% [markdown]
# **3.3** Has the number of recorded crimes increased, decreased or remained stable over said period?

# %% [markdown]
# The total crime rate seem to be steadily decreasing over the years - as shown above.

# %% [markdown]
# *(The answer was already present.)*

# %% [markdown]
# **3.4** By how many percentage points has the crime rate increased/decreased over this period?
#
# Hint: You only need to compare the number of crime records from 2008 with the number of crime records from 2012.

# %%
crime_rate_difference = yearly_records_df["# Of Records"][2008] - yearly_records_df["# Of Records"][2012]
pct_decrease = crime_rate_difference/yearly_records_df["# Of Records"][2008]*100
print(f"The crime rate has decreased by {pct_decrease:1.2f}% from 2008 to 2012.")
# Out:
# The crime rate has decreased by 21.27% from 2008 to 2012.

# %% [markdown]
# **3.5** Which primary crime types have increasing crime rates, and which ones have decreasing crime rates, when comparing 2008 to 2012?

# %%
crimes_2008_mask = chicago_crime_2008_to_2012_df["Date"].dt.year == 2008
crimes_2008_df = chicago_crime_2008_to_2012_df[crimes_2008_mask]
crime_types_2008 = pd.DataFrame(crimes_2008_df["Primary Type"].value_counts()).rename(columns={"count": "Cases 2008"})

crimes_2012_mask = chicago_crime_2008_to_2012_df["Date"].dt.year == 2012
crimes_2012_df = chicago_crime_2008_to_2012_df[crimes_2012_mask]
crime_types_2012 = pd.DataFrame(crimes_2012_df["Primary Type"].value_counts()).rename(columns={"count": "Cases 2012"})

crime_types_2008_and_2012 = pd.merge(crime_types_2008, crime_types_2012, how="outer", on="Primary Type")

# There are crime types that occured during one year, but not the other, so there are some NaN values which should be replaced by 0.
nan_2008_mask = crime_types_2008_and_2012["Cases 2008"].isnull()
crime_types_2008_and_2012["Cases 2008"][nan_2008_mask] = 0
crime_types_2008_and_2012["Cases 2008"] = crime_types_2008_and_2012["Cases 2008"].astype(int)   # 'NaN's cause the dtype to become float, so we must convert it back to int.

nan_2012_mask = crime_types_2008_and_2012["Cases 2012"].isnull()
crime_types_2008_and_2012["Cases 2012"][nan_2012_mask] = 0
crime_types_2008_and_2012["Cases 2012"] = crime_types_2008_and_2012["Cases 2012"].astype(int)

rate_increase_mask = (crime_types_2008_and_2012["Cases 2012"] - crime_types_2008_and_2012["Cases 2008"]) > 0
rate_decrease_mask = (crime_types_2008_and_2012["Cases 2012"] - crime_types_2008_and_2012["Cases 2008"]) < 0
rate_same_mask = (crime_types_2008_and_2012["Cases 2012"] - crime_types_2008_and_2012["Cases 2008"]) == 0
crime_types_2008_and_2012["Rate Increase/Decrease"] = ""
crime_types_2008_and_2012["Rate Increase/Decrease"][rate_increase_mask] = "Increase"
crime_types_2008_and_2012["Rate Increase/Decrease"][rate_decrease_mask] = "Decrease"
crime_types_2008_and_2012["Rate Increase/Decrease"][rate_same_mask] = "Same"
crime_types_2008_and_2012
# Out:
#                                   Cases 2008  Cases 2012  \
# Primary Type
# ARSON                                    644         469
# ASSAULT                                25448       19899
# BATTERY                                75930       59133
# BURGLARY                               26218       22844
# CRIM SEXUAL ASSAULT                     1508        1384
# CRIMINAL DAMAGE                        52843       35855
# CRIMINAL SEXUAL ASSAULT                   58          81
# CRIMINAL TRESPASS                      12310        8216
# DECEPTIVE PRACTICE                     14936       13774
# GAMBLING                                1199         724
# HOMICIDE                                 513         515
# INTERFERENCE WITH PUBLIC OFFICER         580        1228
# INTIMIDATION                             261         156
# KIDNAPPING                               359         235
# LIQUOR LAW VIOLATION                     912         573
# ...

# %% [markdown]
# # 4 - Chicago Police Departement performance assesment

# %% [markdown]
# **4.1** How many recorded crimes have in total led to an arrest? What's the corresponding arrest percentage?

# %%
arrest_count = chicago_crime_2008_to_2012_df["Arrest"].value_counts()
arrest_pct = arrest_count[True]/arrest_count.sum()*100

print(f"There are {arrest_count[True]} recorded crimes which lead to an arrest.")
print(f"It represents {arrest_pct:1.2f}% of all recorded crimes.")
# Out:
# There are 508403 recorded crimes which lead to an arrest.
# It represents 27.06% of all recorded crimes.

# %% [markdown]
# **4.2** Has the arrest rate percentage been increasing, decreasing or remained stable over these years?

# %%
years = chicago_crime_2008_to_2012_df["Year"].unique()
years.sort()
year_masks = {year: chicago_crime_2008_to_2012_df["Year"] == year for year in years}
arrest_rate_df = pd.DataFrame({"Year": years,
                               "# Of Crimes": [len(chicago_crime_2008_to_2012_df[year_masks[year]]) for year in years],
                               "# Of Arrests": [chicago_crime_2008_to_2012_df[year_masks[year]]["Arrest"].sum() for year in years]})
arrest_rate_df["Arrest Rate (%)"] = arrest_rate_df["# Of Arrests"]/arrest_rate_df["# Of Crimes"]*100
arrest_rate_df
# Out:
#    Year  # Of Crimes  # Of Arrests  Arrest Rate (%)
# 0  2008       427198        110026        25.755270
# 1  2009       392848        110841        28.214729
# 2  2010       370541        100555        27.137348
# 3  2011       352020         96302        27.356968
# 4  2012       336344         90679        26.960196

# %%
sns.lineplot(arrest_rate_df, x="Year", y="Arrest Rate (%)", )
plt.title("Yearly Arrest Rate")
plt.ylim(0, 100)
plt.xticks(years)
plt.yticks(range(0, 101, 5))
plt.grid(True, axis="y")

plt.show()

# %% [markdown]
# **Answer:** The arrest rate percentage has remained fairly stable between 25-30%.

# %% [markdown]
# **4.3** For the Year 2011, which month has the highest arrest percentage?

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
crimes_2011_mask = chicago_crime_2008_to_2012_df["Year"] == 2011
crimes_2011_df = chicago_crime_2008_to_2012_df[crimes_2011_mask]
arrest_pct_2011_df = pd.DataFrame({"Month": months,
                                   "# Of Crimes": [(crimes_2011_df["Date"].dt.month_name() == m).sum() for m in months],
                                   "# Of Arrests": [((crimes_2011_df["Date"].dt.month_name() == m) & crimes_2011_df["Arrest"]).sum() for m in months]})
arrest_pct_2011_df["Arrest Rate (%)"] = arrest_pct_2011_df["# Of Arrests"]/arrest_pct_2011_df["# Of Crimes"]*100
arrest_pct_2011_df
# Out:
#         Month  # Of Crimes  # Of Arrests  Arrest Rate (%)
# 0     January        27232          7862        28.870447
# 1    February        22242          6496        29.206007
# 2       March        28702          8410        29.301094
# 3       April        29116          7912        27.174062
# 4         May        31600          8154        25.803797
# 5        June        32328          8566        26.497154
# 6        July        33265          8862        26.640613
# 7      August        32604          9043        27.735861
# 8   September        29946          8288        27.676484
# 9     October        30291          7973        26.321350
# 10   November        27661          7448        26.925997
# 11   December        27033          7288        26.959642

# %%
ax = sns.barplot(arrest_pct_2011_df, x="Arrest Rate (%)", y="Month")
ax.bar_label(ax.containers[0], fmt=lambda pct: f"{pct:1.2f}%", label_type="center", color="white")
plt.title("Arrest Rate in 2011")
plt.xticks()

plt.show()

# %% [markdown]
# **Answer:** March has the highest arrest percentage in 2011.

# %% [markdown]
# **4.4** For the same year, and the particular month of you've identified in question 4.3, which primary crime type has the highest number of arrests?

# %%
crimes_march_2011_mask = (chicago_crime_2008_to_2012_df["Date"].dt.year == 2011) & (chicago_crime_2008_to_2012_df["Date"].dt.month == 3)
arrests_march_2011_mask = crimes_march_2011_mask & chicago_crime_2008_to_2012_df["Arrest"]
arrests_march_2011_df = chicago_crime_2008_to_2012_df[arrests_march_2011_mask]
arrests_march_2011_df["Primary Type"].value_counts()
# Out:
# Primary Type
# NARCOTICS                           3747
# BATTERY                             1285
# THEFT                                611
# CRIMINAL TRESPASS                    599
# ASSAULT                              440
# OTHER OFFENSE                        243
# CRIMINAL DAMAGE                      236
# WEAPONS VIOLATION                    211
# PROSTITUTION                         201
# PUBLIC PEACE VIOLATION               201
# DECEPTIVE PRACTICE                   169
# MOTOR VEHICLE THEFT                   83
# ROBBERY                               81
# BURGLARY                              80
# INTERFERENCE WITH PUBLIC OFFICER      56
# LIQUOR LAW VIOLATION                  45
# OFFENSE INVOLVING CHILDREN            40
# GAMBLING                              21
# SEX OFFENSE                           20
# CRIM SEXUAL ASSAULT                   16
# HOMICIDE                               8
# INTIMIDATION                           7
# ...

# %% [markdown]
# **Answer:** In march 2011, narcotics has the highest number of arrests recorded.

# %% [markdown]
# # 5 - Troubles at home

# %% [markdown]
# **5.1** How many recorded crimes are domestic?

# %%
domestic_counts = chicago_crime_2008_to_2012_df["Domestic"].value_counts()

print(f"There are {domestic_counts[True]} recorded crimes in the data set which are domestic.")
# Out:
# There are 309806 recorded crimes in the data set which are domestic.

# %% [markdown]
# **5.2** How many domestic recorded crimes are of the primary type *offense involving children*?

# %%
domestic_primary_type_counts = chicago_crime_2008_to_2012_df[["Domestic", "Primary Type"]].value_counts()
num_domestic_offense_children = domestic_primary_type_counts[True]["OFFENSE INVOLVING CHILDREN"]

print(f"There are {num_domestic_offense_children} recorded crimes which are domestic and of primary type 'offense involving children'.")
# Out:
# There are 10954 recorded crimes which are domestic and of primary type 'offense involving children'.

# %% [markdown]
# **5.3** How much more likely is it that an offense involving children is domestic?

# %%
num_non_domestic_offense_children = domestic_primary_type_counts[False]["OFFENSE INVOLVING CHILDREN"]
domestic_offense_children_ratio = num_domestic_offense_children/num_non_domestic_offense_children

print(f"It is approximately {domestic_offense_children_ratio:.2f} times more likely that an offense involving children is domestic.")
# Out:
# It is approximately 6.21 times more likely that an offense involving children is domestic.

# %% [markdown]
# **5.4** What's the worst weekday in terms of number of domestic offenses involving children? How does it compare to the other weekdays?

# %%
domestic_offense_children_mask = chicago_crime_2008_to_2012_df["Domestic"] & (chicago_crime_2008_to_2012_df["Primary Type"] == "OFFENSE INVOLVING CHILDREN")
domestic_offense_children_df = chicago_crime_2008_to_2012_df[domestic_offense_children_mask]
weekday_cases_df = pd.DataFrame(domestic_offense_children_df["Date"].dt.day_name().value_counts()).rename(columns={"count": "Count"}).rename_axis("Weekday")
weekday_cases_df
# Out:
#            Count
# Weekday
# Friday      2028
# Saturday    1720
# Sunday      1686
# Thursday    1438
# Tuesday     1396
# Wednesday   1375
# Monday      1311

# %% [markdown]
# **Answer:** Friday is the worst weekday.

# %% [markdown]
# **5.5** What's the distribution, in terms of number of records, for domestic crimes of sexual character that involves children? What's the arrest rate (%) for each?

# %%
sexual_char_iucr_codes = ["1537", "1582", "1751", "1752", "1753", "1754"]   # IUCR codes with primary type 'OFFENSE INVOLVING CHILDREN' and description containing sexual charactaristics.
                                                                            # Taken from https://data.cityofchicago.org/Public-Safety/Chicago-Police-Department-Illinois-Uniform-Crime-R/c7ck-438e/data_preview
sexual_domestic_offense_children_mask = domestic_offense_children_df["IUCR"].isin(sexual_char_iucr_codes)
sexual_domestic_offense_children_df = domestic_offense_children_df[sexual_domestic_offense_children_mask]
sexual_domestic_offense_children_total_df = pd.DataFrame({"IUCR": sexual_char_iucr_codes,
                                                           "# Of Crimes": domestic_offense_children_df["IUCR"].value_counts()[sexual_char_iucr_codes],
                                                           "Status": "Total"}).set_index("IUCR", drop=True)
sexual_domestic_offense_children_arrest_df = pd.DataFrame({"IUCR": sexual_char_iucr_codes,
                                                           "# Of Crimes": domestic_offense_children_df[["Arrest", "IUCR"]].value_counts()[True][sexual_char_iucr_codes],
                                                           "Status": "Arrest"}).set_index("IUCR", drop=True)
sexual_domestic_offense_children_total_df["Arrest Rate (%)"] = sexual_domestic_offense_children_arrest_df["# Of Crimes"]/sexual_domestic_offense_children_total_df["# Of Crimes"]*100
sexual_domestic_offense_children_arrest_df["Arrest Rate (%)"] = sexual_domestic_offense_children_arrest_df["# Of Crimes"]/sexual_domestic_offense_children_total_df["# Of Crimes"]*100
sexual_domestic_offense_children_total_arrest_df = pd.concat([sexual_domestic_offense_children_total_df, sexual_domestic_offense_children_arrest_df])

sexual_domestic_offense_children_total_arrest_df
# Out:
#       # Of Crimes  Status  Arrest Rate (%)
# IUCR
# 1537            4   Total        50.000000
# 1582           21   Total        19.047619
# 1751          486   Total        13.991770
# 1752          795   Total        22.767296
# 1753          356   Total        21.910112
# 1754          659   Total        29.438543
# 1537            2  Arrest        50.000000
# 1582            4  Arrest        19.047619
# 1751           68  Arrest        13.991770
# 1752          181  Arrest        22.767296
# 1753           78  Arrest        21.910112
# 1754          194  Arrest        29.438543

# %%
ax = sns.barplot(sexual_domestic_offense_children_total_arrest_df, x="IUCR", y="# Of Crimes", hue="Status")

plt.title("Offense Involving Children of Sexual Character - Crime and Arrest Rate\n2008-2012")
plt.bar_label(ax.containers[0], fmt=lambda x: f"{int(x)}")
plt.bar_label(ax.containers[1], fmt=lambda x: f"{int(x)}")

plt.show()

# %%
ax = sns.barplot(sexual_domestic_offense_children_total_arrest_df, x="IUCR", y="Arrest Rate (%)")
ax.set_title("Offense Involving Children of Sexual Character - Arrest Rate Percentage\n2008-2012")
ax.set_ylim(0, 100)
ax.bar_label(ax.containers[0], fmt=lambda x: f"{x:1.2f}%")

plt.show()

# %% [markdown]
# **5.6** What period of the day does the specific kind of (domestic) offense against children, with the most recorded arrests, tend do occur? How does it look for all weekdays individually?
#         Can you find certain periods of the week that are especially bad?
#
#     Note: the details of this question is up to you to interpret

# %% [markdown]
# **5.7** Looking at any given year as a whole, what's the worst period in terms of domestic number of offenses involving children? Can you find any trends? Does the trend seem to be consistent for every other year?
#
#     Note: the details of this question is up to you to interpret

# %% [markdown]
# # 6 - Bad Boys Bad Boys whatcha gonna do

# %% [markdown]
# **6.1** In general, what weekday is a crime most likely to occur? Which day is the safest?

# %%
def weekday_crime_counts(df: pd.DataFrame, crime_type: str | None = None) -> pd.DataFrame:
    if crime_type is None:
        return pd.DataFrame(df["Date"].dt.day_name().value_counts().rename_axis("Weekday"))
    else:
        type_mask = df["Primary Type"] == crime_type
        return pd.DataFrame(df[type_mask]["Date"].dt.day_name().value_counts().rename_axis("Weekday"))

# %%
weekday_crime_counts(chicago_crime_2008_to_2012_df)
# Out:
#             count
# Weekday
# Friday     284113
# Wednesday  273628
# Tuesday    271301
# Thursday   269174
# Saturday   266336
# Monday     263017
# Sunday     251382

# %% [markdown]
# **Answer:** Friday is the most likely weekday for a crime to occur. Sunday is the safest weekday.

# %% [markdown]
# **6.2** Which is the most unsafe weekday for you if you'd like to avoid the following:
#
# a) getting your phone stolen by sneaky pickpockets (THEFT)
#
# b) having your handbag forcibly pulled away (ROBBERY)
#
# c) getting jumped in an alley (ASSAULT)

# %%
# a)
weekday_crime_counts(chicago_crime_2008_to_2012_df, "THEFT")
# Out:
#            count
# Weekday
# Friday     61648
# Tuesday    57866
# Wednesday  57726
# Thursday   56836
# Monday     56695
# Saturday   56559
# Sunday     49458

# %% [markdown]
# **Answer:** Friday is the most unsafe.

# %%
# b)
weekday_crime_counts(chicago_crime_2008_to_2012_df, "ROBBERY")
# Out:
#            count
# Weekday
# Friday     10975
# Monday     10780
# Wednesday  10632
# Saturday   10622
# Sunday     10564
# Tuesday    10548
# Thursday   10305

# %% [markdown]
# **Answer:** Friday is the most unsafe.

# %%
# c)
weekday_crime_counts(chicago_crime_2008_to_2012_df, "ASSAULT")
# Out:
#            count
# Weekday
# Wednesday  16969
# Tuesday    16348
# Thursday   16163
# Friday     15972
# Monday     15742
# Saturday   14521
# Sunday     14441

# %% [markdown]
# **Answer:** Wednesday is the most unsafe.

# %% [markdown]
# **6.3** Which are the worst 10 dates (most recorded crimes) of 2008? Does this trend hold for the other years?

# %%
def top_10_crime_dates(df: pd.DataFrame, year: int) -> pd.DataFrame:
    year_2008_mask = df["Year"] == year
    return pd.DataFrame(df[year_2008_mask]["Date"].dt.date.value_counts().head(10))

# %%
top_10_crime_dates(chicago_crime_2008_to_2012_df, 2008)
# Out:
#             count
# Date
# 2008-01-01   1831
# 2008-08-01   1531
# 2008-11-01   1480
# 2008-09-01   1469
# 2008-10-10   1453
# 2008-05-01   1450
# 2008-10-31   1444
# 2008-08-22   1440
# 2008-06-01   1438
# 2008-08-15   1436

# %% [markdown]
# **6.4** From the perspective of total number of crime records, which are the Top 10 primary crime types? Which are the Bottom 10?
#
# Consider this question for the years 2008-2012 as a whole.

# %% [markdown]
# **6.5** For all those crime categories you identified in 6.4, how does their distribution instead look per year - rather than the full 2008-2012 period as a whole?

# %% [markdown]
# **6.6** Which primary crime types does the city of Chicago seem to get better at preventing? For which ones is it the opposite, i.e, the situation is getting worse?

# %% [markdown]
# # 7 - Night Stalker

# %% [markdown]
# **7.1** Are there more or less crimes reported during daytime, compared with nighttime? Daytime is considered as all hours between 06:00-18:00, nighttime is the rest of the day.

# %%
daytime_crimes_mask = chicago_crime_2008_to_2012_df["Date"].dt.hour.between(6, 17)
daytime_crimes_df = chicago_crime_2008_to_2012_df[daytime_crimes_mask]
nighttime_crimes_df = chicago_crime_2008_to_2012_df[~daytime_crimes_mask]

print(f"There are {len(daytime_crimes_df)} recorded crimes during daytime.")
print(f"There are {len(nighttime_crimes_df)} recorded crimes during nighttime.")
print()
if len(daytime_crimes_df) > len(nighttime_crimes_df):
    print("There are more crimes reported during daytime.")
elif len(daytime_crimes_df) < len(nighttime_crimes_df):
    print("There are more crimes reported during nighttime.")
else:
    print("There are an equal amount of crimes crimes reported during daytime and nighttime.")
# Out:
# There are 962889 recorded crimes during daytime.
# There are 916062 recorded crimes during nighttime.
#
# There are more crimes reported during daytime.

# %% [markdown]
# **7.2** Are there any specific primary crime types that most often occur during nights? Which ones are they?

# %%
daytime_type_counts_df = pd.DataFrame(daytime_crimes_df["Primary Type"].value_counts()).rename(columns={"count": "# Of Cases (Day)"})
nighttime_type_counts_df = pd.DataFrame(nighttime_crimes_df["Primary Type"].value_counts()).rename(columns={"count": "# Of Cases (Night)"})
day_night_type_counts_df = pd.merge(daytime_type_counts_df, nighttime_type_counts_df, "outer", on="Primary Type").fillna(0)
day_night_type_counts_df["# Of Cases (Day)"] = day_night_type_counts_df["# Of Cases (Day)"].astype(int)
day_night_type_counts_df.head()
# Out:
#                      # Of Cases (Day)  # Of Cases (Night)
# Primary Type
# ARSON                             710                2045
# ASSAULT                         63625               46531
# BATTERY                        149407              179977
# BURGLARY                        84406               44465
# CRIM SEXUAL ASSAULT              2274                4784

# %%
mostly_night_crimes_mask = day_night_type_counts_df["# Of Cases (Day)"] < day_night_type_counts_df["# Of Cases (Night)"]
mostly_night_crimes = list(day_night_type_counts_df.index[mostly_night_crimes_mask])

print("Crimes that mostly occur during nighttime:")
for crime in mostly_night_crimes:
    print(f"- {crime}")
# Out:
# Crimes that mostly occur during nighttime:
# - ARSON
# - BATTERY
# - CRIM SEXUAL ASSAULT
# - CRIMINAL DAMAGE
# - CRIMINAL SEXUAL ASSAULT
# - GAMBLING
# - HOMICIDE
# - HUMAN TRAFFICKING
# - INTERFERENCE WITH PUBLIC OFFICER
# - LIQUOR LAW VIOLATION
# - MOTOR VEHICLE THEFT
# - NARCOTICS
# - PROSTITUTION
# - PUBLIC INDECENCY
# - PUBLIC PEACE VIOLATION
# - ROBBERY
# - WEAPONS VIOLATION

# %% [markdown]
# **7.3** In general, for each weekday, how many crimes are recorded during daytime and how many during nighttime? What are the trends? Are there any weekdays that stands out somehow?

# %% [markdown]
# Monday, Tuesday, Wednesday, Thursday and Friday have overwhelmingly more recorded crimes during the day, than during the night.
#
# Saturday also has more records during the day, but it's only slightly more than durnig the night.
#
# Sunday is a trend breaker - wherein the number of recorded crimes are higher during the night, than during the night. Though not by alot.

# %% [markdown]
# **7.4** Does the trends you've found in 7.3 also hold if you look at each year individually?

# %% [markdown]
# **7.5** Are there any weekdays in which Stalking occurs more often during nighttime?

# %% [markdown]
# # 8 - Grand Theft Auto

# %% [markdown]
# **8.1** You just bought a new car. What weekday should you be most wary of as it has the highest risk for a Grand Theft Auto-style robbery (MOTOR VEHICLE THEFT)?

# %%
gta_mask = chicago_crime_2008_to_2012_df["Primary Type"] == "MOTOR VEHICLE THEFT"
gta_df = chicago_crime_2008_to_2012_df[gta_mask]
gta_df["Date"].dt.day_name().value_counts()
# Out:
# Date
# Friday       13622
# Thursday     13058
# Wednesday    13045
# Monday       13027
# Tuesday      12714
# Saturday     12106
# Sunday       11698
# Name: count, dtype: int64

# %% [markdown]
# **Answer:** I should be most wary of Fridays.

# %% [markdown]
# **8.2** For that day, where (at what location) should you absolutely avoid leave your car carelessly? Where is it seemingly safest to do so?

# %%
friday_mask = chicago_crime_2008_to_2012_df["Date"].dt.day == 4
friday_gta_df = gta_df[friday_mask]
friday_gta_df["Location"].value_counts().head()
# Out:
# Location
# (41.735857166, -87.624152861)    5
# (41.793065099, -87.738831483)    4
# (41.80462016, -87.684368169)     3
# (41.932930738, -87.636207661)    2
# (41.888993854, -87.626934833)    2
# Name: count, dtype: int64

# %% [markdown]
# **8.3*** Are there certain periods of the year/month/day/time of day where GTA is more frequent?

# %%
def timeline_graph(x: list, y: Callable[[Any], int] | list[int], title: str, xticks: list | None = None) -> plt.Axes:
    if isinstance(y, Callable):
        ax = sns.lineplot(x=x, y=[y(x_val) for x_val in x])
    else:
        ax = sns.lineplot(x=x, y=y)
    ax.set_title(title)
    if xticks is not None:
        ax.set_xticks(xticks)
    ax.set_xlim(x[0], x[-1])
    if isinstance(x[0], str):
        plt.setp(ax.get_xticklabels(), rotation=45, ha="right")
    ax.grid()

# %%
months = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
timeline_graph(months, lambda m: (gta_df["Date"].dt.month_name() == m).sum(), "GTA - Monthly Crime Rate\n2008-2012")
plt.show()

# %% [markdown]
# **Analysis:** GTA occurs most often during summertime, with its peak in July.

# %%
months = pd.to_datetime(pd.Series([f"{month}" for month in range(1, 13)]), format="%m")
days_per_month = months.dt.days_in_month

for i, month in enumerate(months.dt.month_name()):
    month_mask = gta_df["Date"].dt.month_name() == month
    days = list(range(1, days_per_month[i] + 1))
    timeline_graph(days, lambda d: (gta_df[month_mask]["Date"].dt.day == d).sum(), f"GTA - Daily Crime Rate in {month}\n2008-2012", days)
    plt.show()

# %%
hours = list(range(0, 24))
timeline_graph(hours, lambda h: (gta_df["Date"].dt.hour == h).sum(), "GTA - Hourly Crime Rate\n2008-2012")
plt.show()

# %% [markdown]
# **Analysis:** GTA happens most often during the evening, with its peak at hour 22.

# %% [markdown]
# # 9. Just send me like location

# %% [markdown]
# https://www.youtube.com/watch?v=k7yBJ5Ffkdo

# %% [markdown]
# **9.1** Are there any (geographical) areas hit particularly hard by prostitution on friday nights?

# %%
prostitution_mask = chicago_crime_2001_to_2024_df["Primary Type"] == "PROSTITUTION"
friday_mask = chicago_crime_2008_to_2012_df["Date"].dt.weekday == 4
night_mask = ~chicago_crime_2008_to_2012_df["Date"].dt.hour.between(6, 17)
community_area_prostitution_counts = chicago_crime_2001_to_2024_df[prostitution_mask & friday_mask & night_mask]["Community Area"].value_counts()
pd.DataFrame(community_area_prostitution_counts).head()
# Out:
#                 count
# Community Area
# 25.0              138
# 27.0               77
# 26.0               69
# 61.0               63
# 8.0                62

# %% [markdown]
# **Answer:** When looking at the column called 'Community Area', the community area with number code 25 has the highest number of recorded crimes by a clear margine for prostitution on fridays nights. On the web page https://data.cityofchicago.org/Facilities-Geographic-Boundaries/Boundaries-Community-Areas-current-/cauq-8yn6 you can see that the community area with number code 25 is Austin.

# %% [markdown]
# **9.2** Can you vizualise the locations from 9.1 on a map of Chicago? Is there a concentration somewhere?

# %% [markdown]
# **9.3*** Can you find any geographical concentration of other crime categories? Perhaps even by weekday and or day/nighttime? Plot these on a map of Chicago.

# %% [markdown]
# # 10 - The $ factor

# %% [markdown]
# **10.1** Merge the crime and census datasets together in a suitable way.

# %% [markdown]
# **10.2*** Are there certain kinds of socioeconomic area that are more prone to certain kinds of crimes? Do a deep dive in the direction you fancy yourself here.

# %% [markdown]
# # 11 - Your turn!

# %% [markdown]
# There are obviously so much more to gain by analysing these datasets. This is now your opportunity to dwelve deeper into what you yourself like.
#
#     Instructions: think of one or several questions (as we've done above). Then, proceed with your own deep dive analysis and provide your answers.

# %%
valid_coordinates_mask = chicago_crime_2008_to_2012_df["Longitude"].between(-88, -87.4) & chicago_crime_2008_to_2012_df["Latitude"].between(41.6, 42.1)
valid_coordinates_df = chicago_crime_2008_to_2012_df[valid_coordinates_mask][["Longitude", "Latitude"]]

long_step = 2
lat_step = 1

long_range = [val/100 for val in range(-8796, -8745, long_step)]
lat_range = [val/100 for val in range(4164, 4205, lat_step)]
coordinate_count = [((long, lat), (valid_coordinates_df["Longitude"].between(long - long_step/200, long + long_step/200) & valid_coordinates_df["Latitude"].between(lat - lat_step/200, lat + lat_step/200)).sum()) for long in long_range for lat in lat_range]
region_crime_rates_df = pd.DataFrame({"Longitude": [coord[0] for coord, _ in coordinate_count],
                                      "Latitude": [coord[1] for coord, _ in coordinate_count],
                                      "Crime Count": [count for _, count in coordinate_count]})

# %%
sns.scatterplot(region_crime_rates_df, x="Longitude", y="Latitude", hue="Crime Count", size="Crime Count", sizes=(0, 80))
plt.title("Chicago Geographic Crime Rate\n2008-2012")
plt.xlim(-88.2, -87.2)
plt.ylim(41.6, 42.1)
plt.show()
